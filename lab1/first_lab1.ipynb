# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('Immunotherapy.csv', sep=';')

# %%
print(len(train))
# Out:
# 90

# %%
sns.countplot(x='Result_of_Treatment', data=train)
#большинство успешно излечилось

# %%
sns.countplot(x='sex', data=train)
#

# %%
sns.countplot(data=train, hue='sex', x='Result_of_Treatment')

# %%
sns.heatmap(train.corr(), annot=True)
